# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pankaj1281/flyrank_ml_internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os

REPO_URL = "https://github.com/pankaj1281/flyrank_ml_internship.git"
REPO_PATH = "/content/flyrank_ml_internship"

if not os.path.exists(REPO_PATH):
    # !git clone {REPO_URL}

print("Repository ready.")
# Out:
# Repository ready.

# %%
import pandas as pd
import numpy as np

DATA_PATH = "/content/flyrank_ml_internship/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(DATA_PATH)

print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (30000, 44)

# %% [markdown]
# ## 1. My Lane as an ML Task
#
# I chose the **Content Refresh** lane.
#
# This is a **classification** problem because the goal is to classify webpages into two groups: pages that should be prioritized for content refresh and pages that do not need immediate attention. The model will use features such as CTR, impressions, average position, and content age to support this decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or Proxy
#
# The target is whether a webpage needs a content refresh. Since this label is not directly available, I will use the **trend_direction** column as a proxy. Pages with a **down** trend will be treated as pages needing a content refresh, while pages with other trends will be treated as lower priority. This proxy is based on an observed trend in the dataset rather than a confirmed outcome.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success Metric
#
# The primary success metric is **Precision**. High precision means that most pages recommended for content refresh are actually good candidates, reducing unnecessary work for the content team. Recall and F1-score can also be used to evaluate overall model performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The Unit of Analysis
#
# The unit of analysis is **one webpage**. Each row in the dataset represents a single webpage and contains features such as impressions, CTR, average position, and trend direction.

# %%
print("Columns:")
print(df.columns.tolist())
# Out:
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
df["needs_refresh"] = (df["trend_direction"] == "down").astype(int)

df[["trend_direction", "needs_refresh"]].head()
# Out:
#   trend_direction  needs_refresh
# 0            down              1
# 1            down              1
# 2            down              1
# 3          stable              0
# 4            down              1

# %%
print(df["needs_refresh"].value_counts())
# Out:
# needs_refresh
# 1    16262
# 0    13738
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Why ML Beats a Fixed Rule
#
# A fixed rule cannot effectively combine multiple factors such as impressions, CTR, average position, content age, and trend direction. Machine learning can identify patterns across these features and provide better decision support than using a single threshold or simple if-statement. The model is intended to assist decision-making, while the final decision should still involve human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
